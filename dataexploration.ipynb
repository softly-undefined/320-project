# %% [markdown]
# # Data Exploration Notebook!
#
# This document contains our data preprocessing and some basic data exploration and summary statistics

# %%
#Imports
import pandas as pd

# %%
# Extracting the names of each table to identify where to look for 
# data which could provide insight into Taiwan-China relationships
for i in range(1, 95):
    df = pd.read_csv(f"taiwandata/y{i:03}.csv")
    print(df.iloc[3][0])
# Out:
# Table 1. Land, agricultural land and forest land areas
# Table 2. The mean temperature
# Table 3. General situation of population
# Table 4. Number and rates of births, deaths, immigrants and emigrants, marriages and divorces
# Table 5. Fertility rates of childbearing age women
# Table 6. Life expectancy and death rates by 5-year age group
# Table 7. Indicators of labor force status
# Table 8. Employed persons by industry
# Table 9. Unemployment rates by educational attainment and age
# Table 10. Average monthly total earnings per employee on payrolls of establishments by industry
# Table 11. Educational situation
# Table 12. Expenditure situation on education
# Table 13. Primary and junior high school
# Table 14. Senior secondary schools
# Table 15. Higher Education
# Table 16. Number of overseas compatriot Chinese students in all levels of schools
# Table 17. Summary of R&D personnel
# Table 18. Summary of R&D expenditure
# Table 19. Number of patent applications and grant
# ...

# %% [markdown]
# > From here we identified which ones we wanted to use: (list)

# %% [markdown]
# # Test 1: Does Mainland China Investment = Better Taiwanese GDP
# Small test of hypothesis testing; will be looking for the influence of Mainland China investment on Taiwanese GDP using tables 48 (Approved Mainland China investment) and 44 (Gross domestic product and expenditure)

# %%
df48 = pd.read_csv("taiwandata/y048.csv")
df48 = df48.drop(df.index[:7])
df48.head(10)
# definitely work to do here to clean it up, i think we probably just work with the Total investment? 
# unless any questions with specific industries
# Out:
#       88  Unnamed: 1          Unnamed: 2
# 7    NaN         NaN                 NaN  \
# 8    NaN         NaN                 NaN
# 9    NaN         NaN                 NaN
# 10  1991         NaN             17415.8
# 11  1996         NaN            122924.1
# 12  2001         NaN            278414.7
# 13  2006         NaN         764233.5414
# 14  2011         NaN  1437662.4483999999
# 15   NaN         NaN                 NaN
# 16  2012         NaN       1279207.71156
#
#                                            Unnamed: 3           Unnamed: 4
# 7   Agricul-\nture, forestry, fishing & animal hus...  Mining & quarry-ing  \
# 8                                                 NaN                  NaN
# 9                                                 NaN                  NaN
# 10                                                  0                   90
# 11                                                710                735.5
# ...

# %%
df44 = pd.read_csv("taiwandata/y044.csv")
df44.head(30) #this one only has 2014-2021 :( probably have to get more data to supplement for hypothesis test?
# Out:
#            NATIONAL ECONOMICS AND BUSINESS ACTIVITIES  Unnamed: 1
# 0                                                 NaN         NaN  \
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3    Table 44. Gross domestic product and expenditure         NaN
# 4                                   At current prices         NaN
# 5                                                 NaN         NaN
# 6                                                Item         NaN
# 7                                                 NaN         NaN
# 8                                                 NaN         NaN
# 9                                                 NaN         NaN
# 10                          Compensation of employees         NaN
# 11                                  Operating surplus         NaN
# 12                       Consumption of fixed capital         NaN
# ...
